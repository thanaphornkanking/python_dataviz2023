# %% [markdown]
# <a href="https://colab.research.google.com/github/thanaphornkanking/python_dataviz2023/blob/main/final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Members
# - นางสาวจารุพร การร้อย 643021261-5
# - นางสาวเพ็ญพิชชา วรรณ์ชูมาตร์ 643020063-4
# - นางสาวนัฐวดี ชื่นชวนชม 633020986-5
# - นายธนพร ก้านกิ่ง 643021264-9
# - นางสาวอิงอร พลพาล 643021279-6
# - นางสาวธิติพร หิงพุดซา 63021267-3

# %% [markdown]
# # Read data
# ใช้เฉพาะ
# data ปี 20171207-20171219

# %% [markdown]
# # คำถามที่ตะแสดงใน Dashboard
#
# ```
# 1. หาว่า
# - คนที่ใช้ cash มีกี่คน (รวมทั้ง Service & Self-Service)
# - คนที่ใช้ card มีกี่คน (รวมทั้ง Service & Self-Service)
#
# 2.พนักงานที่ใช้เวลาในการคิดเงินไม่เกิน 20 วินาที
#
# 3.ยอดขายรวมของแต่ละวันเป็นเท่าไหร่
#
# 4.ในปี 2017 มีลูกค้ามาซื้อสินค้ามูลค่าสูงสุด ต่ำสุด เท่าไหร่ และโดยเฉลี่ยลูกค้าซื้อของคนละเท่าไหร่
#
# 5.ในแต่ละวันมีลูกค้าเข้ามาซื้อของทั้งหมดวันละกี่ชิ้น

# %% [markdown]
# # Dashboard
#
# [ข้อความลิงก์](https://lookerstudio.google.com/reporting/fdbf991c-5e45-46e1-bd38-448912013ca7)

# %%
import pandas as pd

# %%
operator2017= pd.read_csv('/content/drive/MyDrive/DataViz23Data/final/สำเนาของ POS_operator_logs_20171207-20171219.csv')
operator2017
# Out:
#       WorkstationGroupID  WorkstationID           TranID        BeginDateTime  \
# 0                      8             16    1712071060162  2017-12-07T06:04:01
# 1                      8             15    1712071060152  2017-12-07T06:04:15
# 2                      8             14    1712071060142  2017-12-07T06:05:36
# 3                      8             18    1712071060182  2017-12-07T06:05:41
# 4                      8             17    1712071060172  2017-12-07T06:05:56
# ...                  ...            ...              ...                  ...
# 4703                   8             14  171219106014514  2017-12-19T22:00:22
# 4704                   1             21  171219106021873  2017-12-19T22:02:53
# 4705                   8             15  171219106015506  2017-12-19T22:05:05
# 4706                   1             21  171219106021890  2017-12-19T22:09:47
# 4707                   1             22  171219106022935  2017-12-19T22:12:44
#
# ...

# %%
tran2017= pd.read_csv('/content/drive/MyDrive/DataViz23Data/final/สำเนาของ POS_transactions_20171207-20171219.csv')
tran2017
# Out:
#        WorkstationGroupID           TranID        BeginDateTime  \
# 0                       1  171207106022464  2017-12-07T14:23:23
# 1                       1  171207106022465  2017-12-07T14:25:09
# 2                       1  171207106022466  2017-12-07T14:27:28
# 3                       1  171207106022467  2017-12-07T14:28:04
# 4                       1  171207106022468  2017-12-07T14:29:40
# ...                   ...              ...                  ...
# 66858                   1    1712191060847  2017-12-19T11:48:35
# 66859                   1    1712191060848  2017-12-19T11:49:47
# 66860                   1    1712191060849  2017-12-19T11:50:39
# 66861                   1    1712191060851  2017-12-19T11:51:36
# 66862                   1    1712191060853  2017-12-19T11:52:37
#
#                EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0      2017-12-07T14:24:36         101        73         33      23    True
# ...

# %%
operator2017# ข้อมูลการซื้อสินค้าของปี 20171207-20171219
# Out:
#       WorkstationGroupID  WorkstationID           TranID        BeginDateTime  \
# 0                      8             16    1712071060162  2017-12-07T06:04:01
# 1                      8             15    1712071060152  2017-12-07T06:04:15
# 2                      8             14    1712071060142  2017-12-07T06:05:36
# 3                      8             18    1712071060182  2017-12-07T06:05:41
# 4                      8             17    1712071060172  2017-12-07T06:05:56
# ...                  ...            ...              ...                  ...
# 4703                   8             14  171219106014514  2017-12-19T22:00:22
# 4704                   1             21  171219106021873  2017-12-19T22:02:53
# 4705                   8             15  171219106015506  2017-12-19T22:05:05
# 4706                   1             21  171219106021890  2017-12-19T22:09:47
# 4707                   1             22  171219106022935  2017-12-19T22:12:44
#
# ...

# %%
tran2017 #ข้อมูลการ lock in เครื่องของแคชเชียร์ของปี 20171207-20171219
# Out:
#        WorkstationGroupID           TranID        BeginDateTime  \
# 0                       1  171207106022464  2017-12-07T14:23:23
# 1                       1  171207106022465  2017-12-07T14:25:09
# 2                       1  171207106022466  2017-12-07T14:27:28
# 3                       1  171207106022467  2017-12-07T14:28:04
# 4                       1  171207106022468  2017-12-07T14:29:40
# ...                   ...              ...                  ...
# 66858                   1    1712191060847  2017-12-19T11:48:35
# 66859                   1    1712191060848  2017-12-19T11:49:47
# 66860                   1    1712191060849  2017-12-19T11:50:39
# 66861                   1    1712191060851  2017-12-19T11:51:36
# 66862                   1    1712191060853  2017-12-19T11:52:37
#
#                EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0      2017-12-07T14:24:36         101        73         33      23    True
# ...

# %% [markdown]
# # Check null

# %%
tran2017.isnull().any()
operator2017.isnull().any()

# เช็คแล้วไม่มีค่าว่าง
# Out:
# WorkstationGroupID    False
# WorkstationID         False
# TranID                False
# BeginDateTime         False
# OperatorID            False
# Items                 False
# dtype: bool

# %% [markdown]
# # รวมตารางเพื่อทำ Dashboard

# %% [markdown]
# *

# %%
trans_merge = tran2017.merge(operator2017, on= 'OperatorID', how='left')
print (trans_merge.shape)
trans_merge
# Out:
# (7328682, 16)
#          WorkstationGroupID_x         TranID_x      BeginDateTime_x  \
# 0                           1  171207106022464  2017-12-07T14:23:23
# 1                           1  171207106022464  2017-12-07T14:23:23
# 2                           1  171207106022464  2017-12-07T14:23:23
# 3                           1  171207106022464  2017-12-07T14:23:23
# 4                           1  171207106022464  2017-12-07T14:23:23
# ...                       ...              ...                  ...
# 7328677                     1    1712191060853  2017-12-19T11:52:37
# 7328678                     1    1712191060853  2017-12-19T11:52:37
# 7328679                     1    1712191060853  2017-12-19T11:52:37
# 7328680                     1    1712191060853  2017-12-19T11:52:37
# 7328681                     1    1712191060853  2017-12-19T11:52:37
#
#                  EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# ...

# %%
trans_merge = tran2017.merge(operator2017, on= 'OperatorID', how='left')
print (trans_merge.shape)
trans_merge
# Out:
# (7328682, 16)
#          WorkstationGroupID_x         TranID_x      BeginDateTime_x  \
# 0                           1  171207106022464  2017-12-07T14:23:23
# 1                           1  171207106022464  2017-12-07T14:23:23
# 2                           1  171207106022464  2017-12-07T14:23:23
# 3                           1  171207106022464  2017-12-07T14:23:23
# 4                           1  171207106022464  2017-12-07T14:23:23
# ...                       ...              ...                  ...
# 7328677                     1    1712191060853  2017-12-19T11:52:37
# 7328678                     1    1712191060853  2017-12-19T11:52:37
# 7328679                     1    1712191060853  2017-12-19T11:52:37
# 7328680                     1    1712191060853  2017-12-19T11:52:37
# 7328681                     1    1712191060853  2017-12-19T11:52:37
#
#                  EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# ...

# %%
trans_merge.head()
# Out:
#    WorkstationGroupID_x         TranID_x      BeginDateTime_x  \
# 0                     1  171207106022464  2017-12-07T14:23:23
# 1                     1  171207106022464  2017-12-07T14:23:23
# 2                     1  171207106022464  2017-12-07T14:23:23
# 3                     1  171207106022464  2017-12-07T14:23:23
# 4                     1  171207106022464  2017-12-07T14:23:23
#
#            EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0  2017-12-07T14:24:36         101        73         33      23    True
# 1  2017-12-07T14:24:36         101        73         33      23    True
# 2  2017-12-07T14:24:36         101        73         33      23    True
# 3  2017-12-07T14:24:36         101        73         33      23    True
# 4  2017-12-07T14:24:36         101        73         33      23    True
#
#    TNcard  Amount  WorkstationGroupID_y  WorkstationID         TranID_y  \
# 0   False  112.71                     1             22  171207106022462
# ...

# %%
trans_merge.isnull().any()  #เช็คดูว่ามีค่าว่างมั้ย
# Out:
# WorkstationGroupID_x    False
# TranID_x                False
# BeginDateTime_x         False
# EndDateTime             False
# OperatorID              False
# TranTime                False
# BreakTime               False
# ArtNum                  False
# TNcash                  False
# TNcard                  False
# Amount                  False
# WorkstationGroupID_y    False
# WorkstationID           False
# TranID_y                False
# BeginDateTime_y         False
# Items                   False
# dtype: bool

# %%
#trans_merge.to_csv('result2017', index=False)
#!cp result2017.csv "/content/drive/MyDrive/DataViz23Data/final"

# %%
#2017
trans_merge2017 = trans_merge.filter(items = ['Items','OperatorID', 'EndDateTime',
                                          'WorkstationGroupID_x','WorkstationGroupID_y','TranTime','OperatorID','Amount','ArtNum'], axis = 1 )
trans_merge2017
# Out:
#                    Items  OperatorID          EndDateTime  \
# 0         OperatorSignOn         101  2017-12-07T14:24:36
# 1           OperatorLock         101  2017-12-07T14:24:36
# 2         OperatorUnLock         101  2017-12-07T14:24:36
# 3           OperatorLock         101  2017-12-07T14:24:36
# 4         OperatorUnLock         101  2017-12-07T14:24:36
# ...                  ...         ...                  ...
# 7328677     OperatorLock         606  2017-12-19T11:53:39
# 7328678   OperatorUnLock         606  2017-12-19T11:53:39
# 7328679     OperatorLock         606  2017-12-19T11:53:39
# 7328680   OperatorUnLock         606  2017-12-19T11:53:39
# 7328681  OperatorSignOff         606  2017-12-19T11:53:39
#
#          WorkstationGroupID_x  WorkstationGroupID_y  TranTime  OperatorID  \
# 0                           1                     1        73         101
# 1                           1                     1        73         101
# ...

# %%
test17=tran2017.merge(operator2017[['OperatorID','Items']],how= 'left',on='OperatorID')
test17
# Out:
#          WorkstationGroupID           TranID        BeginDateTime  \
# 0                         1  171207106022464  2017-12-07T14:23:23
# 1                         1  171207106022464  2017-12-07T14:23:23
# 2                         1  171207106022464  2017-12-07T14:23:23
# 3                         1  171207106022464  2017-12-07T14:23:23
# 4                         1  171207106022464  2017-12-07T14:23:23
# ...                     ...              ...                  ...
# 7328677                   1    1712191060853  2017-12-19T11:52:37
# 7328678                   1    1712191060853  2017-12-19T11:52:37
# 7328679                   1    1712191060853  2017-12-19T11:52:37
# 7328680                   1    1712191060853  2017-12-19T11:52:37
# 7328681                   1    1712191060853  2017-12-19T11:52:37
#
#                  EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# 0        2017-12-07T14:24:36         101        73         33      23    True
# ...

# %%
test18 = test17.drop_duplicates(subset=['TranID'])
print(test18.shape)
test18.reset_index()
# Out:
# (66863, 12)
#          index  WorkstationGroupID           TranID        BeginDateTime  \
# 0            0                   1  171207106022464  2017-12-07T14:23:23
# 1          258                   1  171207106022465  2017-12-07T14:25:09
# 2          516                   1  171207106022466  2017-12-07T14:27:28
# 3          774                   1  171207106022467  2017-12-07T14:28:04
# 4         1032                   1  171207106022468  2017-12-07T14:29:40
# ...        ...                 ...              ...                  ...
# 66858  7328342                   1    1712191060847  2017-12-19T11:48:35
# 66859  7328410                   1    1712191060848  2017-12-19T11:49:47
# 66860  7328478                   1    1712191060849  2017-12-19T11:50:39
# 66861  7328546                   1    1712191060851  2017-12-19T11:51:36
# 66862  7328614                   1    1712191060853  2017-12-19T11:52:37
#
#                EndDateTime  OperatorID  TranTime  BreakTime  ArtNum  TNcash  \
# ...

# %%
import os
os.chdir('/content/drive/MyDrive/new_test')
# !pwd #เช็ค path ที่กำลังทำงานอยู่
# Out:
# /content/drive/MyDrive/new_test

# %%
test18.to_csv('result_new.csv', index=False)

# %%
test18.isnull().any()
# Out:
# WorkstationGroupID    False
# TranID                False
# BeginDateTime         False
# EndDateTime           False
# OperatorID            False
# TranTime              False
# BreakTime             False
# ArtNum                False
# TNcash                False
# TNcard                False
# Amount                False
# Items                 False
# dtype: bool

# %%
ans3 = test18.filter(items = ['OperatorID','TranTime']).reset_index()
ans3
# Out:
#          index  OperatorID  TranTime
# 0            0         101        73
# 1          258         101       111
# 2          516         101        20
# 3          774         101        25
# 4         1032         101        52
# ...        ...         ...       ...
# 66858  7328342         606        53
# 66859  7328410         606        37
# 66860  7328478         606        43
# 66861  7328546         606        52
# 66862  7328614         606        62
#
# [66863 rows x 3 columns]

# %%
ans3 = test18.filter(items = ['OperatorID','TranTime']).reset_index()
ans3

# %%
ans6 = test18.filter(items = ['TranID','ArtNum','OperatorID','Amount']).reset_index()
ans6
# Out:
#          index           TranID  ArtNum  OperatorID  Amount
# 0            0  171207106022464      23         101  112.71
# 1          258  171207106022465      29         101   54.76
# 2          516  171207106022466       3         101   14.77
# 3          774  171207106022467      12         101   37.88
# 4         1032  171207106022468       7         101  115.34
# ...        ...              ...     ...         ...     ...
# 66858  7328342    1712191060847       6         606   36.27
# 66859  7328410    1712191060848      10         606   43.16
# 66860  7328478    1712191060849      11         606   39.58
# 66861  7328546    1712191060851       9         606  113.96
# 66862  7328614    1712191060853      25         606   97.58
#
# [66863 rows x 5 columns]

# %%
ans6.to_csv('ans6.csv', index=False)
