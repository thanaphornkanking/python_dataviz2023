# %% [markdown]
# <a href="https://colab.research.google.com/github/thanaphornkanking/python_dataviz2023/blob/main/%E0%B8%95%E0%B8%B4%E0%B8%A7%E0%B9%83%E0%B8%AB%E0%B9%89%E0%B9%80%E0%B8%9E%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%99%E0%B8%9B%E0%B8%A5%E0%B8%B2%E0%B8%A2%E0%B8%A0%E0%B8%B2%E0%B8%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # นำข้อมูลเข้า

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
import pandas as pd
df = pd.read_excel('/content/drive/MyDrive/drive ฝึก python fo final/ectreport2023.xlsx')
result_constituencies_PartyList = pd.read_excel('/content/drive/MyDrive/drive ฝึก python fo final/ectreport2023.xlsx',sheet_name='result_constituencies_PartyList')
result_constituencies_Candidate = pd.read_excel('/content/drive/MyDrive/drive ฝึก python fo final/ectreport2023.xlsx',sheet_name='result_constituencies_Candidate')
result_constituencies_status = pd.read_excel('/content/drive/MyDrive/drive ฝึก python fo final/ectreport2023.xlsx',sheet_name='result_constituencies_status')
info_province = pd.read_excel('/content/drive/MyDrive/drive ฝึก python fo final/ectreport2023.xlsx',sheet_name='info_province')
info_party_overview = pd.read_excel('/content/drive/MyDrive/drive ฝึก python fo final/ectreport2023.xlsx',sheet_name='info_party_overview')
info_constituency = pd.read_excel('/content/drive/MyDrive/drive ฝึก python fo final/ectreport2023.xlsx',sheet_name='info_constituency')
Candidate_Constituency = pd.read_excel('/content/drive/MyDrive/drive ฝึก python fo final/ectreport2023.xlsx',sheet_name='Candidate_Constituency')
Candidate_PartyList = pd.read_excel('/content/drive/MyDrive/drive ฝึก python fo final/ectreport2023.xlsx',sheet_name='Candidate_PartyList')
Candidate_PM = pd.read_excel('/content/drive/MyDrive/drive ฝึก python fo final/ectreport2023.xlsx',sheet_name='Candidate_PM')

# %%
df1 = pd.read_csv('/content/drive/MyDrive/drive ฝึก python fo final/creditcard_2023.csv', index_col=0)
df1.head()
# Out:
#           V1        V2        V3        V4        V5        V6        V7  \
# id
# 0  -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2  -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3  -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4  -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#           V8        V9       V10  ...       V21       V22       V23       V24  \
# id                                ...
# 0  -0.130006  0.727159  0.637735  ... -0.110552  0.217606 -0.134794  0.165959
# 1  -0.133118  0.347452  0.529808  ... -0.194936 -0.605761  0.079469 -0.577395
# 2  -0.095576 -0.261297  0.690708  ... -0.005020  0.702906  0.945045 -1.154666
# 3  -0.065130 -0.205698  0.575231  ... -0.146927 -0.038212 -0.214048 -1.893131
# 4  -0.212660  1.049921  0.968046  ... -0.106984  0.729727 -0.161666  0.312561
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 568630 entries, 0 to 568629
# Data columns (total 30 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   V1      568630 non-null  float64
#  1   V2      568630 non-null  float64
#  2   V3      568630 non-null  float64
#  3   V4      568630 non-null  float64
#  4   V5      568630 non-null  float64
#  5   V6      568630 non-null  float64
#  6   V7      568630 non-null  float64
#  7   V8      568630 non-null  float64
#  8   V9      568630 non-null  float64
#  9   V10     568630 non-null  float64
#  10  V11     568630 non-null  float64
#  11  V12     568630 non-null  float64
#  12  V13     568630 non-null  float64
#  13  V14     568630 non-null  float64
#  14  V15     568630 non-null  float64
#  15  V16     568630 non-null  float64
#  16  V17     568630 non-null  float64
#  17  V18     568630 non-null  float64
#  18  V19     568630 non-null  float64
#  19  V20     568630 non-null  float64
# ...

# %%
df1.describe()
# Out:
#                  V1            V2            V3            V4            V5  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean  -5.638058e-17 -1.319545e-16 -3.518788e-17 -2.879008e-17  7.997245e-18
# std    1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min   -3.495584e+00 -4.996657e+01 -3.183760e+00 -4.951222e+00 -9.952786e+00
# 25%   -5.652859e-01 -4.866777e-01 -6.492987e-01 -6.560203e-01 -2.934955e-01
# 50%   -9.363846e-02 -1.358939e-01  3.528579e-04 -7.376152e-02  8.108788e-02
# 75%    8.326582e-01  3.435552e-01  6.285380e-01  7.070047e-01  4.397368e-01
# max    2.229046e+00  4.361865e+00  1.412583e+01  3.201536e+00  4.271689e+01
#
#                  V6            V7            V8            V9           V10  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean  -3.958636e-17 -3.198898e-17  2.109273e-17  3.998623e-17  1.991314e-16
# ...

# %%
result_constituencies_Candidate.describe()
# Out:
#        mp_app_rank   mp_app_vote  mp_app_vote_percent     party_id
# count  4781.000000   4781.000000          4781.000000  4781.000000
# mean      6.711985   7654.289898             8.223124   733.349090
# std       3.845837  12389.868008            19.185614    23.968199
# min       1.000000      0.000000             0.000000   701.000000
# 25%       3.000000    300.000000             0.309190   709.000000
# 50%       6.000000    780.000000             0.809330   729.000000
# 75%      10.000000  11738.000000            12.227910   762.000000
# max      20.000000  63185.000000           714.909760   786.000000

# %%
result_constituencies_Candidate[result_constituencies_Candidate['mp_app_vote_percent']>100]
# Out:
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id
# 0   NST_6   NST_6_5            1        27331            714.90976       743
# 1   NST_6   NST_6_9            2        23260            608.42270       709
# 2   NST_6   NST_6_8            3        10700            279.88491       726
# 3   NST_6  NST_6_10            4         7731            202.22338       763
# 4   NST_6   NST_6_1            5         5596            146.37719       705
# 5   NST_6   NST_6_4            6         5574            145.80173       701

# %% [markdown]
# #วิธีดูค่า null

# %%
info_party_overview.isnull().any() #เช็คว่าอันไหนมี null
# Out:
# id          False
# party_no     True
# name        False
# abbr        False
# color       False
# logo_url    False
# dtype: bool

# %% [markdown]
# # กำจัด null

# %% [markdown]
# ## drop na

# %%
print(info_party_overview.shape)
info_party_overview.dropna()
# Out:
# (70, 6)
#      id  party_no           name    abbr    color  \
# 0   701      26.0   ประชาธิปัตย์    ปชป.  #06aff3
# 1   702      63.0     ประชากรไทย    ปชท.  #0f41ce
# 2   703      60.0   ความหวังใหม่    ควม.  #e6b750
# 3   705      29.0       เพื่อไทย     พท.  #da3731
# 4   706      14.0  ชาติพัฒนากล้า    ชพก.  #233e8a
# ..  ...       ...            ...     ...      ...
# 65  780      55.0    ไทยก้าวหน้า    ทกน.  #b9bee3
# 66  781       9.0           พลัง      พ.  #8e8fc7
# 67  783      52.0  ชาติรุ่งเรือง    ชรร.  #9cb4c9
# 68  784      23.0       รวมใจไทย  ร.จ.ท.  #eec49a
# 69  786      20.0        เปลี่ยน      ป.  #cc898a
#
#                                              logo_url
# 0   https://cdn.ectreport.com/images/logos/ประชาธิ...
# 1   https://cdn.ectreport.com/images/logos/ประชากร...
# 2   https://cdn.ectreport.com/images/logos/ความหวั...
# 3   https://cdn.ectreport.com/images/logos/เพื่อไท...
# 4   https://cdn.ectreport.com/images/logos/ชาติพัฒ...
# ...

# %% [markdown]
# ## fillna()

# %%
fixparty_no = info_party_overview.fillna(99)
fixparty_no
# Out:
#      id  party_no           name    abbr    color  \
# 0   701      26.0   ประชาธิปัตย์    ปชป.  #06aff3
# 1   702      63.0     ประชากรไทย    ปชท.  #0f41ce
# 2   703      60.0   ความหวังใหม่    ควม.  #e6b750
# 3   705      29.0       เพื่อไทย     พท.  #da3731
# 4   706      14.0  ชาติพัฒนากล้า    ชพก.  #233e8a
# ..  ...       ...            ...     ...      ...
# 65  780      55.0    ไทยก้าวหน้า    ทกน.  #b9bee3
# 66  781       9.0           พลัง      พ.  #8e8fc7
# 67  783      52.0  ชาติรุ่งเรือง    ชรร.  #9cb4c9
# 68  784      23.0       รวมใจไทย  ร.จ.ท.  #eec49a
# 69  786      20.0        เปลี่ยน      ป.  #cc898a
#
#                                              logo_url
# 0   https://cdn.ectreport.com/images/logos/ประชาธิ...
# 1   https://cdn.ectreport.com/images/logos/ประชากร...
# 2   https://cdn.ectreport.com/images/logos/ความหวั...
# 3   https://cdn.ectreport.com/images/logos/เพื่อไท...
# 4   https://cdn.ectreport.com/images/logos/ชาติพัฒ...
# ...

# %%
info_party_overview[info_party_overview['party_no'].isnull()]
# Out:
#      id  party_no          name  abbr    color  \
# 9   711       NaN  ประชาสามัคคี   ปส.  #ecb55e
# 11  713       NaN     พลังบูรพา   พบ.  #4696d6
# 17  720       NaN     รักษ์ธรรม  ร.ธ.  #dbdc9c
#
#                                              logo_url
# 9   https://cdn.ectreport.com/images/logos/ประชาสา...
# 11  https://cdn.ectreport.com/images/logos/พลังบูร...
# 17  https://cdn.ectreport.com/images/logos/รักษ์ธร...

# %%
fixparty_no[fixparty_no['party_no']==99]# ผ่านการ fill(na) มาแล้ว
# Out:
#      id  party_no          name  abbr    color  \
# 9   711      99.0  ประชาสามัคคี   ปส.  #ecb55e
# 11  713      99.0     พลังบูรพา   พบ.  #4696d6
# 17  720      99.0     รักษ์ธรรม  ร.ธ.  #dbdc9c
#
#                                              logo_url
# 9   https://cdn.ectreport.com/images/logos/ประชาสา...
# 11  https://cdn.ectreport.com/images/logos/พลังบูร...
# 17  https://cdn.ectreport.com/images/logos/รักษ์ธร...

# %% [markdown]
# # marge
#
# concat ต่อตูด

# %%
con_id1=result_constituencies_Candidate[result_constituencies_Candidate['cons_id']=='ACR_1']

# %%
con_id2=result_constituencies_Candidate[result_constituencies_Candidate['cons_id']=='ACR_2']

# %%
con_id3=result_constituencies_Candidate[result_constituencies_Candidate['cons_id']=='AYA_1']

# %%
con_id1
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 268    ACR_1  ACR_1_10            1        38275             36.25419
# 790    ACR_1   ACR_1_8            2        21388             20.25878
# 1016   ACR_1   ACR_1_6            3        16724             15.84102
# 1050   ACR_1   ACR_1_5            4        15926             15.08515
# 1675   ACR_1   ACR_1_9            5         2825              2.67585
# 1696   ACR_1   ACR_1_3            6         2701              2.55840
# 2052   ACR_1   ACR_1_7            7         1281              1.21337
# 2669   ACR_1   ACR_1_4            8          668              0.63273
# 3172   ACR_1   ACR_1_1            9          459              0.43477
# 3926   ACR_1   ACR_1_2           10          234              0.22165
# 4020   ACR_1  ACR_1_13           11          212              0.20081
# 4380   ACR_1  ACR_1_12           12          127              0.12029
# ...

# %%
con_id2
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 148    ACR_2  ACR_2_10            1        46881             41.92804
# 942    ACR_2   ACR_2_1            2        19188             17.16080
# 1020   ACR_2   ACR_2_3            3        17637             15.77366
# 1086   ACR_2   ACR_2_9            4        16009             14.31766
# 1743   ACR_2   ACR_2_5            5         2530              2.26271
# 1834   ACR_2   ACR_2_2            6         2027              1.81285
# 2148   ACR_2   ACR_2_7            7         1156              1.03387
# 3075   ACR_2   ACR_2_6            8          519              0.46417
# 3493   ACR_2   ACR_2_8            9          378              0.33806
# 4115   ACR_2   ACR_2_4           10          197              0.17619
# 4132   ACR_2  ACR_2_11           11          193              0.17261
# 4214   ACR_2  ACR_2_12           12          173              0.15472
#
#       party_id
# 148        709
# 942        726
# ...

# %%
meow = pd.concat([con_id1,con_id2])
meow
# Out:
#      cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 268    ACR_1  ACR_1_10            1        38275             36.25419
# 790    ACR_1   ACR_1_8            2        21388             20.25878
# 1016   ACR_1   ACR_1_6            3        16724             15.84102
# 1050   ACR_1   ACR_1_5            4        15926             15.08515
# 1675   ACR_1   ACR_1_9            5         2825              2.67585
# 1696   ACR_1   ACR_1_3            6         2701              2.55840
# 2052   ACR_1   ACR_1_7            7         1281              1.21337
# 2669   ACR_1   ACR_1_4            8          668              0.63273
# 3172   ACR_1   ACR_1_1            9          459              0.43477
# 3926   ACR_1   ACR_1_2           10          234              0.22165
# 4020   ACR_1  ACR_1_13           11          212              0.20081
# 4380   ACR_1  ACR_1_12           12          127              0.12029
# ...

# %% [markdown]
# ## join

# %%
x1 = con_id1.merge(Candidate_Constituency, on= 'mp_app_id',how='left')

# %%
x2=x1.merge(info_constituency, on= 'cons_id',how='left')

# %%
x2[['cons_id','mp_app_id','party_id','mp_app_name','mp_app_vote','mp_app_vote_percent']]
# Out:
#    cons_id mp_app_id  party_id                mp_app_name  mp_app_vote  \
# 0    ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 1    ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 2    ACR_1   ACR_1_8       705          นางสมหญิง บัวบุตร        21388
# 3    ACR_1   ACR_1_8       705          นางสมหญิง บัวบุตร        21388
# 4    ACR_1   ACR_1_6       726          นายประภาส เวชกรณ์        16724
# 5    ACR_1   ACR_1_6       726          นายประภาส เวชกรณ์        16724
# 6    ACR_1   ACR_1_5       701  นางสาวแป้งธนชาภา จันทวารา        15926
# 7    ACR_1   ACR_1_5       701  นางสาวแป้งธนชาภา จันทวารา        15926
# 8    ACR_1   ACR_1_9       743          นายวิชัย บุญเสริฐ         2825
# 9    ACR_1   ACR_1_9       743          นายวิชัย บุญเสริฐ         2825
# 10   ACR_1   ACR_1_3       763        นายบวรศักดิ์ คณาเสน         2701
# 11   ACR_1   ACR_1_3       763        นายบวรศักดิ์ คณาเสน         2701
# ...

# %%
x3 = x2[['cons_id','mp_app_id','party_id','mp_app_name','mp_app_vote','mp_app_vote_percent']]

# %%
# making a bool series
bool_series = x3.duplicated(subset='mp_app_name')
# passing NOT of bool series to see unique values only
x4 = x3[~bool_series]
# displaying data
x5 = x4.reset_index()
x5
# Out:
#     index cons_id mp_app_id  party_id                mp_app_name  mp_app_vote  \
# 0       0   ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 1       2   ACR_1   ACR_1_8       705          นางสมหญิง บัวบุตร        21388
# 2       4   ACR_1   ACR_1_6       726          นายประภาส เวชกรณ์        16724
# 3       6   ACR_1   ACR_1_5       701  นางสาวแป้งธนชาภา จันทวารา        15926
# 4       8   ACR_1   ACR_1_9       743          นายวิชัย บุญเสริฐ         2825
# 5      10   ACR_1   ACR_1_3       763        นายบวรศักดิ์ คณาเสน         2701
# 6      12   ACR_1   ACR_1_7       762           นายทวีชัย พลธานี         1281
# 7      14   ACR_1   ACR_1_4       719       นายอิทธิกร สุวะมาตย์          668
# 8      16   ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 9      18   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# 10     20   ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# ...

# %% [markdown]
# # การสร้าง data frame

# %%
y = {
  "LOL": ['sc','ss','380','390','lo','po','85','58','sc','ss','380','390','lo']

}

# %%
lol = pd.DataFrame(y)
lol
# Out:
#     LOL
# 0    sc
# 1    ss
# 2   380
# 3   390
# 4    lo
# 5    po
# 6    85
# 7    58
# 8    sc
# 9    ss
# 10  380
# 11  390
# 12   lo

# %%
xlol = x5.join(lol, how = 'left')
xlol
# Out:
#     index cons_id mp_app_id  party_id                mp_app_name  mp_app_vote  \
# 0       0   ACR_1  ACR_1_10       709     นางสุขสมรวย วันทนียกุล        38275
# 1       2   ACR_1   ACR_1_8       705          นางสมหญิง บัวบุตร        21388
# 2       4   ACR_1   ACR_1_6       726          นายประภาส เวชกรณ์        16724
# 3       6   ACR_1   ACR_1_5       701  นางสาวแป้งธนชาภา จันทวารา        15926
# 4       8   ACR_1   ACR_1_9       743          นายวิชัย บุญเสริฐ         2825
# 5      10   ACR_1   ACR_1_3       763        นายบวรศักดิ์ คณาเสน         2701
# 6      12   ACR_1   ACR_1_7       762           นายทวีชัย พลธานี         1281
# 7      14   ACR_1   ACR_1_4       719       นายอิทธิกร สุวะมาตย์          668
# 8      16   ACR_1   ACR_1_1       706      นางสาวปิยะมาศ บัวแก้ว          459
# 9      18   ACR_1   ACR_1_2       769             นายกมล บุญธิมา          234
# 10     20   ACR_1  ACR_1_13       761           นายสงบ โสภิพันธ์          212
# ...

# %% [markdown]
# #loop group by

# %%
meow.groupby('cons_id')['mp_app_vote','mp_app_id'].max().reset_index().sort_values(by='mp_app_vote',ascending=False) # max
# Out:
# <ipython-input-109-11d85f5f04ca>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   meow.groupby('cons_id')['mp_app_vote','mp_app_id'].max().reset_index().sort_values(by='mp_app_vote',ascending=False)
#   cons_id  mp_app_vote mp_app_id
# 1   ACR_2        46881   ACR_2_9
# 0   ACR_1        38275   ACR_1_9

# %%
meow.groupby('cons_id')['mp_app_vote','mp_app_id'].min().reset_index().sort_values(by='mp_app_vote',ascending=True)
# Out:
# <ipython-input-111-a8fe7305deab>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   meow.groupby('cons_id')['mp_app_vote','mp_app_id'].min().reset_index().sort_values(by='mp_app_vote',ascending=True)
#   cons_id  mp_app_vote mp_app_id
# 0   ACR_1          126   ACR_1_1
# 1   ACR_2          173   ACR_2_1

# %%
meow.groupby('cons_id')['mp_app_vote','mp_app_id'].sum().reset_index().sort_values(by='mp_app_vote',ascending=True)
# Out:
# <ipython-input-112-710550d18ee2>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   meow.groupby('cons_id')['mp_app_vote','mp_app_id'].sum().reset_index().sort_values(by='mp_app_vote',ascending=True)
# <ipython-input-112-710550d18ee2>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   meow.groupby('cons_id')['mp_app_vote','mp_app_id'].sum().reset_index().sort_values(by='mp_app_vote',ascending=True)
#   cons_id  mp_app_vote
# 0   ACR_1       100946
# 1   ACR_2       106888

# %%
meow.groupby('cons_id')['mp_app_vote','mp_app_id'].count().reset_index().sort_values(by='mp_app_vote',ascending=True)
# Out:
# <ipython-input-113-52df9b1ddc45>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   meow.groupby('cons_id')['mp_app_vote','mp_app_id'].count().reset_index().sort_values(by='mp_app_vote',ascending=True)
#   cons_id  mp_app_vote  mp_app_id
# 1   ACR_2           12         12
# 0   ACR_1           13         13

# %%
k = ['I','LUV','YOU']
for i in range(len(k)):
  a = k[i]

# %%
len(k)
# Out:
# 3

# %%
info_party_overview['party_no'] = info_party_overview['party_no'].fillna(99)

# %%
table_merge = result_constituencies_Candidate.merge(Candidate_Constituency, how ='left', left_on='mp_app_id',right_on='mp_app_id')
print(table_merge.shape)
table_merge.head()
# Out:
# (4781, 10)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   NST_6   NST_6_5            1        27331            714.90976       743
# 1   NST_6   NST_6_9            2        23260            608.42270       709
# 2   NST_6   NST_6_8            3        10700            279.88491       726
# 3   NST_6  NST_6_10            4         7731            202.22338       763
# 4   NST_6   NST_6_1            5         5596            146.37719       705
#
#                  mp_app_name  mp_app_no  mp_app_party_id  \
# 0          นายสุธรรม จริตงาม          5              743
# 1    นายสมศักดิ์ แสงอารยะกุล          9              709
# 2  นายปิยวัฒน์ สิริพันธ์พงศ์          8              726
# 3         นายฉัตรชัย ธนาวุฒิ         10              763
# 4        นายถาวรวัฒน์ คงแก้ว          1              705
#
#                                            image_url
# 0  https://cdn.ectreport.com/images/mp_candidates...
# ...

# %%
table_merge2 = table_merge.merge(info_party_overview, how ='left', left_on='party_id',right_on='id')
print(table_merge2.shape)
table_merge2.head()
# Out:
# (4781, 16)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   NST_6   NST_6_5            1        27331            714.90976       743
# 1   NST_6   NST_6_9            2        23260            608.42270       709
# 2   NST_6   NST_6_8            3        10700            279.88491       726
# 3   NST_6  NST_6_10            4         7731            202.22338       763
# 4   NST_6   NST_6_1            5         5596            146.37719       705
#
#                  mp_app_name  mp_app_no  mp_app_party_id  \
# 0          นายสุธรรม จริตงาม          5              743
# 1    นายสมศักดิ์ แสงอารยะกุล          9              709
# 2  นายปิยวัฒน์ สิริพันธ์พงศ์          8              726
# 3         นายฉัตรชัย ธนาวุฒิ         10              763
# 4        นายถาวรวัฒน์ คงแก้ว          1              705
#
#                                            image_url   id  party_no  \
# 0  https://cdn.ectreport.com/images/mp_candidates...  743      37.0
# ...

# %%
table_merge3 = table_merge2.merge(result_constituencies_status, how ='left', left_on='cons_id',right_on='cons_id')
print(table_merge3.shape)
table_merge3.head()
# Out:
# (4781, 22)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   NST_6   NST_6_5            1        27331            714.90976       743
# 1   NST_6   NST_6_9            2        23260            608.42270       709
# 2   NST_6   NST_6_8            3        10700            279.88491       726
# 3   NST_6  NST_6_10            4         7731            202.22338       763
# 4   NST_6   NST_6_1            5         5596            146.37719       705
#
#                  mp_app_name  mp_app_no  mp_app_party_id  \
# 0          นายสุธรรม จริตงาม          5              743
# 1    นายสมศักดิ์ แสงอารยะกุล          9              709
# 2  นายปิยวัฒน์ สิริพันธ์พงศ์          8              726
# 3         นายฉัตรชัย ธนาวุฒิ         10              763
# 4        นายถาวรวัฒน์ คงแก้ว          1              705
#
#                                            image_url  ...             name  \
# ...

# %%
table_merge4 = table_merge3.merge(info_province, how ='left', left_on='prov_id',right_on='prov_id')
print(table_merge4.shape)
table_merge4.head()
# Out:
# (4781, 28)
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   NST_6   NST_6_5            1        27331            714.90976       743
# 1   NST_6   NST_6_9            2        23260            608.42270       709
# 2   NST_6   NST_6_8            3        10700            279.88491       726
# 3   NST_6  NST_6_10            4         7731            202.22338       763
# 4   NST_6   NST_6_1            5         5596            146.37719       705
#
#                  mp_app_name  mp_app_no  mp_app_party_id  \
# 0          นายสุธรรม จริตงาม          5              743
# 1    นายสมศักดิ์ แสงอารยะกุล          9              709
# 2  นายปิยวัฒน์ สิริพันธ์พงศ์          8              726
# 3         นายฉัตรชัย ธนาวุฒิ         10              763
# 4        นายถาวรวัฒน์ คงแก้ว          1              705
#
#                                            image_url  ...  percent_turn_out  \
# ...

# %%
(table_merge4.isnull().any())
# Out:
# cons_id                  False
# mp_app_id                False
# mp_app_rank              False
# mp_app_vote              False
# mp_app_vote_percent      False
# party_id                 False
# mp_app_name              False
# mp_app_no                False
# mp_app_party_id          False
# image_url                False
# id                       False
# party_no                 False
# name                     False
# abbr                     False
# color                    False
# logo_url                 False
# prov_id                  False
# turn_out                 False
# percent_turn_out         False
# counted_vote_stations    False
# percent_count            False
# pause_report             False
# province_id              False
# province                 False
# eng                      False
# abbre_thai               False
# total_registered_vote    False
# total_vote_stations      False
# dtype: bool

# %%
table_merge4[table_merge4['mp_app_vote_percent']> 100]
# Out:
#   cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# 0   NST_6   NST_6_5            1        27331            714.90976       743
# 1   NST_6   NST_6_9            2        23260            608.42270       709
# 2   NST_6   NST_6_8            3        10700            279.88491       726
# 3   NST_6  NST_6_10            4         7731            202.22338       763
# 4   NST_6   NST_6_1            5         5596            146.37719       705
# 5   NST_6   NST_6_4            6         5574            145.80173       701
#
#                  mp_app_name  mp_app_no  mp_app_party_id  \
# 0          นายสุธรรม จริตงาม          5              743
# 1    นายสมศักดิ์ แสงอารยะกุล          9              709
# 2  นายปิยวัฒน์ สิริพันธ์พงศ์          8              726
# 3         นายฉัตรชัย ธนาวุฒิ         10              763
# 4        นายถาวรวัฒน์ คงแก้ว          1              705
# 5        นายประกอบ รัตนพันธ์          4              701
#
# ...

# %%
def math_pa(x):
  y=(100*x)/1220778
  return y

# %%
table_merge5 = table_merge4.replace(to_replace=[146.37719,202.22338,145.80173,714.90976,279.88491,608.42270],
           value=[math_pa(146.37719),math_pa(202.22338),math_pa(145.80173),math_pa(714.90976),math_pa(279.88491),math_pa(608.42270)]).sort_values(by='mp_app_vote_percent', ascending=False)

# %%
table_merge6 = table_merge5.groupby('cons_id').max()
table_merge6
# Out:
#         mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  party_id  \
# cons_id
# ACR_1     ACR_1_9           13        38275             36.25419       769
# ACR_2     ACR_2_9           12        46881             41.92804       770
# ATG_1     ATG_1_8            8        44725             49.82954       769
# ATG_2     ATG_2_9            9        47232             51.63886       769
# AYA_1     AYA_1_9           10        41081             37.23905       769
# ...           ...          ...          ...                  ...       ...
# YLA_2     YLA_2_9           15        51946             51.78082       763
# YLA_3     YLA_3_9           14        31741             32.40332       763
# YST_1     YST_1_9           13        53130             48.08536       769
# YST_2     YST_2_9           13        44851             45.56547       769
# YST_3     YST_3_9           11        37946             36.30085       769
#
# ...

# %%
table_merge6 = table_merge5.reset_index().sort_values(by='mp_app_vote_percent', ascending=False)
table_merge6
# Out:
#       index cons_id mp_app_id  mp_app_rank  mp_app_vote  mp_app_vote_percent  \
# 0         6   RET_5   RET_5_3            1        61288             69.34758
# 1         7   CPM_2   CPM_2_6            1        61414             63.43832
# 2         8  UBN_10  UBN_10_1            1        63127             62.27446
# 3         9   TRG_2   TRG_2_6            1        63185             60.29103
# 4        10   KSN_1   KSN_1_9            1        56559             59.80965
# ...     ...     ...       ...          ...          ...                  ...
# 4720   4737   NBP_1   NBP_1_3           13            0              0.00000
# 4719   4776   UBN_4   UBN_4_9           15            0              0.00000
# 4718   4777   UBN_7  UBN_7_14           16            0              0.00000
# 4717   4778   UDN_3  UDN_3_13           15            0              0.00000
# 4780   4780   YST_1   YST_1_9           13            0              0.00000
#
# ...

# %%
papa2.to_csv('final_score_partylist.csv', index=False)
